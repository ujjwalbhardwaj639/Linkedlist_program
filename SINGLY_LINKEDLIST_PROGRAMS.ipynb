# %% [markdown]
# # Programs of LinkedList

# %% [markdown]
# ### CREATION OF NODE

# %%
class Node:
    def __init__(self):
        self.info = None
        self.next = None
node = Node()
node.info = "First Node"
print(node)
print(node.info)
print(node.next)
# Out:
# <__main__.Node object at 0x000002091C32FCA0>
# First Node
# None

# %% [markdown]
# ### CREATION OF LINKED LIST

# %%
class LinkedList:
    def __init__(self):
        self.start=None
SLL=LinkedList()
print(SLL)
# Out:
# <__main__.LinkedList object at 0x000002091C37A040>

# %% [markdown]
# ### CREATE A LINKEDLIST TO STORE NAMES OF THREE FRIENDS

# %%
class Node:
    def __init__(self):
        self.info=None
        self.next=None

class LinkedList:
    def __init__(self):
        self.start=None
    
    def display(self):
        temp=self.start
        while(temp.next!= None):
            print(temp.info,end="-->")
            temp=temp.next
        print(temp.info)
        
SLL=LinkedList()
node1 = Node()
node1.info = "Ujjwal"
node2 = Node()
node2.info = "Shubh"
node3 = Node()
node3.info = "Sauhard"
SLL.start = node1
node1.next = node2
node2.next = node3
SLL.display()
# Out:
# Ujjwal-->Shubh-->Sauhard

# %% [markdown]
# ### Perform CREATION, INSERTION, DELETION SORTING REVERAL AND SEARCHING IN LINKEDLIST

# %%
class Node:
    def __init__(self):
        self.info = None
        self.next = None
        
class Linkedlist:
    def __init__(self):
        self.start = None 
    
    def create(self):
        while(1):
            node = Node()
            node.info = input("Enter info: ")
            if(self.start == None):
                self.start = node
            else:
                temp.next = node
            temp = node 
            choice = input("Do u want to next node? yes/no : ")
            if(choice=="no"):
                break
        print("Linkedlist created successfully.")
          
    def insert_at_beg(self):
        if(self.start == None):
            print("No Linkedlist exists.")
        else:
            node = Node()
            node.info = input("Enter element which u want to insert at beginning: ")
            node.next = self.start 
            self.start = node
        print("Insert element at beginning successfully.")
    
    def insert_at_last(self):
        if(self.start == None):
            print("No Linkedlist exists.")
        else:
            temp = self.start 
            while(temp.next!=None):
                temp = temp.next 
            node = Node()
            node.info = input("Enter element which u want to insert at last: ")
            temp.next = node
        print("Insert element at last successfully.")
    
    def insert_after_desired_node(self,elem):
        if(self.start == None):
            print("No Linkedlist exists.")
        else:
            temp = self.start
            while(temp.next is not None and temp.info!=elem):
                temp = temp.next
            if(temp.next is None):
                print("Element not found")
            else:
                node=Node()
                node.info = input("Enter element which u want to insert after node: ")
                node.next = temp.next
                temp.next = node
        print("Insert element after node successfully.")
            
    def delete_at_beg(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            self.start = self.start.next
        print("Deletion beginning successfully.")
    
    def delete_at_last(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start 
            prev = None
            while(temp.next!=None):
                prev = temp
                temp = temp.next
            if(prev is None):
                self.strat = None
            else:
                prev.next = None
        print("Deletion last successfully.")
            
    def delete_after_desired_node(self,elem):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start
            prev = None
            while(temp is not None and temp.info!=elem):
                prev = temp
                temp = temp.next
            if(temp is None):
                print("Element is does not exists in LinkedList")
            else:
                if(prev is None):
                    self.start = self.start.next
                else:
                    prev.next = temp.next
        print("Deletion after node successfully.")
            
    def search(self,elem):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start
            while(temp is not None and temp.info!=elem):
                temp = temp.next
            if(temp is not None):
                print("Element found in Linkedlist")
            else:
                print("Element not found in Linkedlist")
            
    def sort(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            i = self.start
            while(i.next is not None):
                j = i.next
                while(j is not None):
                    if(i.info>j.info):
                        temp = i.info
                        i.info = j.info
                        j.info = temp
                    j = j.next
                i = i.next
            print("LinkedList sorted successfully")
            
    def reversal(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            prev = None
            curr = self.start
            while(curr is not None):
                temp = curr.next
                curr.next = prev
                prev = curr
                curr = temp
            self.start = prev 
            print("Reversal successfully.")
        
    def display(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start
            while(temp.next!=None):
                print(temp.info,end = "--->")
                temp = temp.next
            print(temp.info)
            print("Linked list displayed successfully.")

# %% [markdown]
# ### Give action from user

# %%
def main():
    SLL = Linkedlist()
    while(True): 
        print("""                   LINKEDLIST PROGRAM 
          1.Create Linkedlist
          2.Insert at beginning
          3.Insert at last
          4.Insert at desired location
          5.Deletion at beginning
          6.Deletion at last
          7.Deletion at desired location
          8.Searching
          9.Sorting
          10.Reversal
          11.Display
          12.Exit""")
        choice = int(input("Enter your choice: "))
        if(choice==1):
            SLL.create()
        elif(choice==2):
            SLL.insert_at_beg()
        elif(choice==3):
            SLL.insert_at_last()
        elif(choice==4):
            elem = input("Enter element where u want to insert next element: ")
            SLL.insert_after_desired_node(elem)
        elif(choice==5):
            SLL.delete_at_beg()
        elif(choice==6):
            SLL.delete_at_last()
        elif(choice==7):
            elem = input("Enter element which u want to delete: ")
            SLL.delete_after_desired_node(elem)
        elif(choice==8):
            elem = input("Enter element which u want to search: ")
            SLL.search(elem)
        elif(choice==9):
            SLL.sort()
        elif(choice==10):
            SLL.reversal()
        elif(choice==11):
            SLL.display()
        elif(choice==12):
            print("Thank you -)")
            break
        else:
            print("Wrong choice")
main()
# Out:
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 1
# Enter info: 13
# Do u want to next node? yes/no : yes
# Enter info: 78
# Do u want to next node? yes/no : no
# Linkedlist created successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 11
# 13--->78
# Linked list displayed successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 2
# Enter element which u want to insert at beginning: 75
# Insert element at beginning successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 11
# 75--->13--->78
# Linked list displayed successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 3
# Enter element which u want to insert at last: 30
# Insert element at last successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 11
# 75--->13--->78--->30
# Linked list displayed successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 4
# Enter element where u want to insert next element: 13
# Enter element which u want to insert after node: 12
# Insert element after node successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 11
# 75--->13--->12--->78--->30
# Linked list displayed successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 12
# Thank you -)

# %%
main()
# Out:
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 1
# Enter info: 34
# Do u want to next node? yes/no : yes
# Enter info: 78
# Do u want to next node? yes/no : yes
# Enter info: 19
# Do u want to next node? yes/no : yes
# Enter info: 19
# Do u want to next node? yes/no : no
# Linkedlist created successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 5
# Deletion beginning successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 11
# 78--->19--->19
# Linked list displayed successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 6
# Deletion last successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 11
# 78--->19
# Linked list displayed successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 7
# Enter element which u want to delete: 78
# Deletion after node successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 11
# 19
# Linked list displayed successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 12
# Thank you -)

# %%
main()
# Out:
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 1
# Enter info: 56
# Do u want to next node? yes/no : yes
# Enter info: 19
# Do u want to next node? yes/no : yes
# Enter info: 12
# Do u want to next node? yes/no : no
# Linkedlist created successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 11
# 56--->19--->12
# Linked list displayed successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 8
# Enter element which u want to search: 19
# Element found in Linkedlist
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 9
# LinkedList sorted successfully
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 11
# 12--->19--->56
# Linked list displayed successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 10
# Reversal successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 11
# 56--->19--->12
# Linked list displayed successfully.
#                    LINKEDLIST PROGRAM
#           1.Create Linkedlist
#           2.Insert at beginning
#           3.Insert at last
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Sorting
#           10.Reversal
#           11.Display
#           12.Exit
# Enter your choice: 12
# Thank you -)
